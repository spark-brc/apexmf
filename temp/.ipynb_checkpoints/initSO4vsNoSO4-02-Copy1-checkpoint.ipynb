# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import datetime
from tqdm import tqdm
# from apexmf import apexmf_pst_viz

# %%
sys.path.append('D:/test/apexmf')
import apexmf_pst_viz, apexmf_pst_utils
from salt.analyzer import SaltAnalysis, SaltViz, get_stats

# %%
wd_zero02 = "d:/Projects/Watersheds/Animas/Analysis/AMRSs/manul_calibration/Animas_AMRS-Fire_so4_zero02"
wd_zero03 = "d:/Projects/Watersheds/Animas/Analysis/AMRSs/manul_calibration/Animas_AMRS-Fire_so4_zero03"
wd_zero04 = "d:/Projects/Watersheds/Animas/Analysis/AMRSs/manul_calibration/Animas_AMRS-Fire_so4_zero04"

wd_test = "d:/Projects/Watersheds/Animas/Analysis/AMRSs/manul_calibration/Animas_AMRS-Fire_so4_test"
# os.chdir(wd)

# %%
sim_start = '1/1/1987'
cal_start = '1/1/1992'
cal_end = '12/31/2011'

# %%
m_zero02 = SaltAnalysis(wd_zero02)
salt_zero2 = m_zero02.load_salt_cha_result()
salt_zero2
# Out:
#           load_so4    load_ca    load_mg    load_na     load_k    load_cl  \
# subarea
# 1             0.00       0.00      0.000      0.000    0.00000      0.000
# 2             0.00       0.00      0.000      0.000    0.00000      0.000
# 3             0.00       0.00      0.000      0.000    0.00000      0.000
# 4             0.00       0.00      0.000      0.000    0.00000      0.000
# 5             0.00       0.00      0.000      0.000    0.00000      0.000
# ...            ...        ...        ...        ...        ...        ...
# 71       399697.06  122178.93  60947.469  47491.344  827.92133  39304.637
# 72       400494.12  122424.41  61070.570  47609.258  829.97833  39508.832
# 73            0.00       0.00      0.000      0.000    0.00000      0.000
# 74       401403.28  122703.84  61210.699  47771.293  832.22418  39744.266
# 75       404131.53  123564.94  61632.117  48193.570  838.69116  40386.098
#
#           load_co3  load_hco3   conc_so4    conc_ca    conc_mg    conc_na  \
# subarea
# 1         0.000000       0.00    0.00000    0.00000    0.00000    0.00000
# 2         0.000000       0.00    0.00000    0.00000    0.00000    0.00000
# 3         0.000000       0.00    0.00000    0.00000    0.00000    0.00000
# 4         0.000000       0.00    0.00000    0.00000    0.00000    0.00000
# 5         0.000000       0.00    0.00000    0.00000    0.00000    0.00000
# ...            ...        ...        ...        ...        ...        ...
# 71       59.708801  132319.77  875.69904  267.68265  133.53023  104.04911
# 72       72.939568  132499.28  875.72040  267.69321  133.53691  104.10239
# 73        0.000000       0.00    0.00000    0.00000    0.00000    0.00000
# 74       73.054985  132711.41  875.78461  267.71613  133.54996  104.22775
# 75       74.226158  133401.31  885.72137  270.81308  135.07703  105.62422
#
#            conc_k    conc_cl  conc_co3  conc_hco3
# subarea
# 1        0.000000   0.000000  0.000000    0.00000
# 2        0.000000   0.000000  0.000000    0.00000
# 3        0.000000   0.000000  0.000000    0.00000
# 4        0.000000   0.000000  0.000000    0.00000
# 5        0.000000   0.000000  0.000000    0.00000
# ...           ...        ...       ...        ...
# 71       1.813898  86.112793  0.130816  289.90030
# 72       1.814831  86.390007  0.159490  289.72293
# 73       0.000000   0.000000  0.000000    0.00000
# 74       1.815753  86.714325  0.159392  289.55072
# 75       1.838131  88.512840  0.162679  292.37112
#
# [684825 rows x 16 columns]

# %%
sim_df02 = m_zero02.read_salt_sim_cha(salt_zero2, 75, sim_start, cal_start, cal_end).resample('M').mean()
sim_df02
# Out:
#                  load_so4        load_ca        load_mg        load_na  \
# 1992-01-31  590001.961290  180860.805806   89793.867903   63765.458452
# 1992-02-29  570226.449310  174889.453448   86814.222793   62459.146034
# 1992-03-31  612887.347097  187396.398065   93256.663000   70712.278806
# 1992-04-30  806907.622333  239741.115000  121608.020333  102134.280333
# 1992-05-31  757247.269355  236734.643226  115012.858129   71906.128129
# ...                   ...            ...            ...            ...
# 2011-08-31  423357.544194  130480.660645   64526.707387   48712.553258
# 2011-09-30  412366.267667  127503.317333   62871.856267   47381.589833
# 2011-10-31  426833.870645  131792.615806   65072.899355   50210.339710
# 2011-11-30  407110.970000  124916.845333   62078.872367   47669.782233
# 2011-12-31  407694.467419  124770.006452   62176.480097   48649.791871
#
#                  load_k       load_cl     load_co3      load_hco3    conc_so4  \
# 1992-01-31  1179.960716  56402.292032   304.490679  189737.798387  562.372195
# 1992-02-29  1142.294776  54807.166966   168.650831  183402.236897  597.379646
# 1992-03-31  1239.320113  65335.156903   537.926423  196793.617097  705.978392
# 1992-04-30  1504.161897  89192.430800  5973.271116  272458.772000  423.290757
# 1992-05-31  1477.216774  63680.752548  2956.050393  233062.886129  273.006736
# ...                 ...           ...          ...            ...         ...
# 2011-08-31   870.514130  41090.961032   753.020237  137541.537742  181.096232
# 2011-09-30   849.306931  39701.300633  1561.543213  134586.013333  177.473972
# 2011-10-31   884.003250  41643.490419  2363.837461  141301.025806  443.950338
# 2011-11-30   843.141411  40235.049600   458.712572  133378.247000  649.188667
# 2011-12-31   845.991252  41016.329774   343.364329  134575.752903  578.515766
#
#                conc_ca     conc_mg    conc_na    conc_k    conc_cl  conc_co3  \
# 1992-01-31  172.374587   85.593745  60.752284  1.125343  53.779854  0.226577
# 1992-02-29  183.223095   90.951899  65.483615  1.197170  57.520924  0.157063
# 1992-03-31  215.573258  107.395167  81.284046  1.424230  74.482852  0.323989
# 1992-04-30  124.045872   63.779317  53.446764  0.783697  47.796352  0.861621
# 1992-05-31   85.262989   41.469113  25.798428  0.532622  22.870526  0.615088
# ...                ...         ...        ...       ...        ...       ...
# 2011-08-31   55.762021   27.600583  20.857241  0.372273  17.612085  0.250478
# 2011-09-30   54.731608   27.058283  20.434321  0.365572  17.164057  0.465551
# 2011-10-31  135.814596   67.676135  52.721275  0.920373  44.155949  0.769264
# 2011-11-30  199.013461   98.994013  76.182953  1.344943  64.380206  0.506853
# 2011-12-31  176.922683   88.229138  68.909903  1.200312  57.981170  0.339130
#
#              conc_hco3
# 1992-01-31  180.853998
# 1992-02-29  192.092509
# 1992-03-31  227.160862
# 1992-04-30  141.929018
# 1992-05-31   83.599656
# ...                ...
# 2011-08-31   58.827006
# 2011-09-30   57.916242
# 2011-10-31  147.073721
# 2011-11-30  212.764976
# 2011-12-31  191.050928
#
# [240 rows x 16 columns]

# %%
f, ax = plt.subplots()
SaltViz(sim_df02).plot_hist(ax, "load_co3", label="mf CA frac: 0.01")
SaltViz(sim_df03).plot_hist(ax, "load_co3", label="mf CA frac: 1")
SaltViz(sim_df04).plot_hist(ax, "load_co3", label="mf CA frac: 100")                          
plt.legend()

# %%
m_zero02 = SaltAnalysis(wd_zero02)
salt_zero2 = m_zero02.load_salt_cha_result()
m_zero03 = SaltAnalysis(wd_zero03)
salt_zero3 = m_zero03.load_salt_cha_result()
m_zero04 = SaltAnalysis(wd_zero04)
salt_zero4 = m_zero04.load_salt_cha_result()

# %%
sim_df03 = m_zero03.read_salt_sim_cha(salt_zero3, 75, sim_start, cal_start, cal_end).resample('M').mean()
sim_df04 = m_zero04.read_salt_sim_cha(salt_zero4, 75, sim_start, cal_start, cal_end).resample('M').mean()

# %%
os.getcwd()
# Out:
# 'd:\\Projects\\Watersheds\\Animas\\Analysis\\AMRSs\\manul_calibration\\Animas_AMRS-Fire_so4_zero04'

# %%
font = {"family": "calibri", "weight": "normal", "size": 12}
plt.rc("font", **font)
f, ax = plt.subplots()
SaltViz(sim_df02).plot_hist(ax, "load_so4", label="mf SO4 frac: 0.01")
SaltViz(sim_df03).plot_hist(ax, "load_so4", label="mf SO4 frac: 1.00")
SaltViz(sim_df04).plot_hist(ax, "load_so4", label="mf SO4 frac: 100")
plt.legend()
f.savefig("salt_loading_histogram.jpg", dpi=300)
plt.show()

# %%
font = {"family": "calibri", "weight": "normal", "size": 12}
plt.rc("font", **font)
f, axes = plt.subplots(1, 3, figsize=(10,3))
SaltViz(sim_df02).plot_hist(axes[0], "load_so4", label="mf SO4 frac: 0.01")
SaltViz(sim_df03).plot_hist(axes[1], "load_so4", label="mf SO4 frac: 1.00")
SaltViz(sim_df04).plot_hist(axes[2], "load_so4", label="mf SO4 frac: 100")
axes[0].legend()
axes[1].legend()
axes[2].legend()

f.savefig("salt_loading_histogram02.jpg", dpi=300, bbox_inches="tight")
plt.show()

# %%
[9,12,75]

# %%
def salt_viz(model, salt_df, subs):
    for i in subs:
        print(f"{'= = '*3}sub{i:03d} {'= = '*3}")
        sim_df = model.read_salt_sim_cha(salt_df, i, sim_start, cal_start, cal_end).resample('M').mean()
        obd_df = model.read_salt_obd_cha(i, time_step='mon')
        obd_df = obd_df[~obd_df.index.duplicated(keep='first')]    
        for o in obd_df.columns:
            comdf = model.sim_obd_df(sim_df, o, obd_df, o)
            print(o)
            print(get_stats(comdf['1/1/1992':'12/31/2011']))
            fig, ax = plt.subplots(1, 2, figsize=(12, 2), gridspec_kw={'width_ratios': [6, 1]})
            SaltViz(comdf['1/1/1992':'12/31/2011']).hydro_sim_obd02(ax[0])
            SaltViz(comdf['1/1/1992':'12/31/2011']).reg_line02(ax[1])
            fig.tight_layout()
            plt.show()

# %%
m_test = SaltAnalysis(wd_test)
salt_test = m_test.load_salt_cha_result()

# %%
m_zero02 = SaltAnalysis(wd_zero02)
salt_zero2 = m_zero02.load_salt_cha_result()
m_zero03 = SaltAnalysis(wd_zero03)
salt_zero3 = m_zero03.load_salt_cha_result()
m_zero04 = SaltAnalysis(wd_zero04)
salt_zero4 = m_zero04.load_salt_cha_result()

# %%
get_stats?

# %%
salt_viz(m_zero02, salt_zero2, [75])
# Out:
# = = = = = = sub075 = = = = = =
# load_so4
# (-19.0436, 336003.006, -199.1135, 0.4185)
# load_na
# (-6.9805, 29382.0009, -97.5488, 0.413)
# load_k
# (-0.9474, 3312.219, 70.8714, 0.3783)
# load_mg
# (-41.9256, 60918.4974, -402.619, 0.4653)
# load_cl
# (-30.4127, 33173.7644, -176.5556, 0.2104)
# load_co3
# (0.085, 7186.2592, 67.2383, 0.5083)
# load_ca
# (-0.1672, 72481.9786, -50.3544, 0.4478)
# load_hco3
# (0.0525, 163227.0878, 28.6477, 0.4007)

# %%
salt_viz(m_zero03, salt_zero3, [75])
# Out:
# = = = = = = sub075 = = = = = =
# load_so4
# (-24717.6822, 11799625.4738, -7051.2026, 0.4386)
# load_na
# (-10.7178, 35603.1739, -119.7167, 0.4272)
# load_k
# (-17.0367, 10080.3303, -283.4339, 0.1635)
# load_mg
# (-102315.3618, 2974155.7469, -19628.1376, 0.4774)
# load_cl
# (-30.4127, 33173.7644, -176.5556, 0.2104)
# load_co3
# (0.0872, 7177.6652, 67.0524, 0.5089)
# load_ca
# (-1.838, 113020.1004, -100.7891, 0.4557)
# load_hco3
# (0.0525, 163227.0878, 28.6477, 0.4007)

# %%
salt_viz(m_zero04, salt_zero4, [75])
# Out:
# = = = = = = sub075 = = = = = =
# load_so4
# (-24724.9505, 11801360.1276, -7052.3098, 0.4388)
# load_na
# (-10.7178, 35603.1739, -119.7167, 0.4272)
# load_k
# (-17.0367, 10080.3303, -283.4339, 0.1635)
# load_mg
# (-102348.6026, 2974638.8331, -19631.5517, 0.4774)
# load_cl
# (-30.4127, 33173.7644, -176.5556, 0.2104)
# load_co3
# (0.0872, 7177.6655, 67.0522, 0.5089)
# load_ca
# (-1.8345, 112951.9454, -100.7101, 0.4554)
# load_hco3
# (0.0525, 163227.0878, 28.6477, 0.4007)

# %%
salt_viz(m_test, salt_test, [75])
# Out:
# = = = = = = sub075 = = = = = =
# load_so4
# (-0.0759, 77846.8758, 28.0808, 0.4137)
# load_na
# (-6.9797, 29380.5849, -97.5434, 0.413)
# load_k
# (-0.9474, 3312.2208, 70.8715, 0.3783)
# load_mg
# (-0.2141, 10245.0301, 40.929, 0.4696)
# load_cl
# (-30.4014, 33167.8155, -176.5209, 0.2103)
# load_co3
# (0.0945, 7149.0291, 66.3789, 0.5101)
# load_ca
# (-0.2451, 74862.1496, 45.339, 0.5004)
# load_hco3
# (0.0525, 163227.1766, 28.647, 0.4007)

# %%
cha_file = 'SITE75.RCH'
subs = [12, 57, 75]
st_date='1/1/1987'
ed_date='12/31/2011'
cal_start = '1/1/1992'
rch_file = 'SITE75.RCH'
obd_nams = ['str_{:03d}'.format(i) for i in subs]

# %%
for i, j in zip(subs, obd_nams):
    df = apexmf_pst_viz.stf_df(cha_file, st_date, i, j, time_step='M')
    df = df['1/1/1992':'12/31/2011']
    apexmf_pst_viz.stf_plot(df)

# %% [markdown]
# # observation data analysis

# %%
obd_df_day = m1.read_salt_obd_cha(sub_id, time_step='day')
obd_df_mon = m1.read_salt_obd_cha(sub_id, time_step='mon')

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(5, 3, figsize=(14, 10))
for i, sub_id in enumerate([9, 12, 75]):
    obd_df = m1.read_salt_obd_cha(sub_id, time_step='day')
    obd_mdf = m1.read_salt_obd_cha(sub_id, time_step='mon')
    for j, obd_nam in enumerate(['load_ca', 'load_mg', 'load_k', 'load_na', 'load_so4']):
        axes[j, i].hist(obd_df[obd_nam], bins=15, alpha=0.5)
        axes[j, i].hist(obd_mdf[obd_nam], bins=15, alpha=0.5)
        axes[j, i].tick_params(axis='both', which='major', labelsize=12)
        
fig.legend(['Daily', 'Monthly Average'], ncols=2, loc='upper center', fontsize=12)
# fig.tight_layout()
plt.show()

# %%
"++"*2
# Out:
# '++++'
